# %%
1+1
# Out:
# 2

# %%
print('foobar')
# Out:
# foobar

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, polar=True)
bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r / 10.))
    bar.set_alpha(0.5)

plt.show()
# Out:
# /Users/harakonan/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/harakonan/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
np.random.randn(3)
# Out:
# array([ 0.26613175,  1.97253271, -0.76207029])

# %%
np.rank?

# %% [markdown]
# If $\{A_n\}$ is pairwise disjoint, then
# $$ \mu(\cup_n A_n) = \sum_m \mu(A_n) $$

# %%
pwd
# Out:
# '/Users/harakonan/Workspace/Python'

# %%
cd QuantEcon.applications/getting_started/
# Out:
# /Users/harakonan/Workspace/Python/QuantEcon.applications/getting_started

# %%
ls
# Out:
# eigenvec.py              first_notebook_py.ipynb  white_noise_plot.py

# %%
# %matplotlib inline

# %%
run white_noise_plot.py

# %%
# %load white_noise_plot.py
from pylab import plot, show, legend
from random import normalvariate

x = [normalvariate(0, 1) for i in range(100)]
plot(x, 'b-', label="white noise")
legend()
show()

# %%
# %%file foo.py
for i in range(5):
    print('foobar')
# Out:
# Writing foo.py

# %%
run foo.py
# Out:
# foobar
# foobar
# foobar
# foobar
# foobar
